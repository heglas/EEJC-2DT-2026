# %% [markdown]
# # Desafio Avançado: Laboratório de Lógica e Ciência de Dados
# **Tema:** Algoritmos complexos, IDE e Manipulação de tipos
# **Objetivo:** Elevar a complexidade com lógica condicional aninhada, conversão de tipos e análise de erros.

# %% [markdown]
# ### Exercício 1: O Verificador de Evento (Lógica Complexa)
# Em vez de uma verificação simples, crie um algoritmo que:
# 1. Receba a nota (float).
# 2. Receba o status de participação (bool).
# 3. Regra: Se a participação for True E a nota >= 6.0, imprima "Certificado Emitido".
# 4. Se a participação for True E nota < 6.0, imprima "Em recuperação".
# 5. Se a participação for False, imprima "Inscrição pendente de comparecimento".

# %%
nota = 5.5
participou = True
# Implemente a estrutura if/elif/else aqui:

# %% [markdown]
# ### Exercício 2: Tratamento e Conversão de Dados
# Recebemos uma lista de dados de um formulário onde tudo veio como String, mas precisamos processar:
# 1. Converta a lista de strings para os tipos adequados (int, float, bool).
# 2. Calcule a média das notas.
# 3. Use um try/except para capturar erros caso a conversão de uma nota falhe.

# %%
dados_brutos = ["8.5", "7.0", "nao_numerico", "9.0"]
# Tente processar e calcular a média com tratamento de erro:
