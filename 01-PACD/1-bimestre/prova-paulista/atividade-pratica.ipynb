# %% [markdown]
# # Aula de Programação Aplicada à Ciência de Dados
# ## Tema: Algoritmos, IDE e Tipos de Dados
# **Duração:** 50 minutos
# **Objetivo:** Praticar a lógica de entrada/processamento/saída e classificação de tipos de dados.

# %% [markdown]
# ### Parte 1: Introdução e Contextualização (10 min)
# Breve discussão sobre o papel do programador e a estrutura de um algoritmo (Entrada, Processamento, Saída).

# %% [markdown]
# ### Parte 2: Desafio Prático - Identificação (15 min)
# **Atividade:** Abaixo, temos um pequeno cenário. Identifique os dados e o tipo esperado.

# %%
# Cenário: Cadastro de um participante de evento
# Nome: "Heglas Oliveira"
# Idade: 35
# Participou do Workshop? (Sim/Não)
# Nota da Avaliação: 9.5

# Defina os tipos para cada variável abaixo:
nome = "Heglas Oliveira" # Tipo: 
idade = 35               # Tipo: 
workshop = True          # Tipo: 
nota = 9.5               # Tipo:

# %% [markdown]
# ### Parte 3: Criando um Algoritmo de Decisão (20 min)
# **Atividade:** Escreva uma lógica (usando if/else) que imprima "Aprovado" se a nota for maior ou igual a 7.0, caso contrário "Em Recuperação".

# %%
nota_aluno = 8.0
# Escreva sua lógica aqui:

# %% [markdown]
# ### Parte 4: Fechamento e Depuração (5 min)
# Discussão sobre possíveis erros comuns (ex: tipos incompatíveis) e dúvidas finais.
